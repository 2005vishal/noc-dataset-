# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #team 1 anlysis

# %%
df = pd.read_csv('team sport.csv')

# %%
df.drop(columns = 'Unnamed: 0',axis = 1,inplace = True)

# %%
df
# Out:
#                                Name Sex   Age  Height  Weight            Team  \
# 0                         A Dijiang   M  24.0   180.0    80.0           China
# 1               Gunnar Nielsen Aaby   M  24.0   195.0    90.0         Denmark
# 2              Edgar Lindenau Aabye   M  34.0   195.0    90.0  Denmark/Sweden
# 3                  Antti Sami Aalto   M  26.0   186.0    96.0         Finland
# 4          Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# ...                             ...  ..   ...     ...     ...             ...
# 45978      Fernando scar Zylberberg   M  27.0   168.0    76.0       Argentina
# 45979    James Francis "Jim" Zylker   M  21.0   175.0    75.0   United States
# 45980  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0          Russia
# 45981  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0          Russia
# 45982        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0         Belarus
#
# ...

# %%
d = df.sort_values(by = 'Age')
plt.plot(range(len(d)),'Age',data = d)

# %%
d = df.sort_values(by = 'Height')
plt.plot(range(len(d)),'Height',data = d)

# %%
d = df.sort_values(by = 'Weight')
plt.plot(range(len(d)),'Weight',data = d)

# %%
sns.lineplot(y = 'Age',x = 'Year',data = df)
# Out:
# <Axes: xlabel='Year', ylabel='Age'>

# %%
sns.distplot(df['Age'],bins = 10,rug = True,hist = False)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\2985974922.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins = 10,rug = True,hist = False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45983 entries, 0 to 45982
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      45983 non-null  object
#  1   Sex       45983 non-null  object
#  2   Age       45983 non-null  float64
#  3   Height    45983 non-null  float64
#  4   Weight    45983 non-null  float64
#  5   Team      45983 non-null  object
#  6   NOC       45983 non-null  object
#  7   Year      45983 non-null  int64
#  8   Season    45983 non-null  object
#  9   City      45983 non-null  object
#  10  Sport     45983 non-null  object
#  11  Event     45983 non-null  object
#  12  category  45983 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 4.6+ MB

# %%
df.head()
# Out:
#                        Name Sex   Age  Height  Weight            Team  NOC  \
# 0                 A Dijiang   M  24.0   180.0    80.0           China  CHN
# 1       Gunnar Nielsen Aaby   M  24.0   195.0    90.0         Denmark  DEN
# 2      Edgar Lindenau Aabye   M  34.0   195.0    90.0  Denmark/Sweden  DEN
# 3          Antti Sami Aalto   M  26.0   186.0    96.0         Finland  FIN
# 4  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland  FIN
#
#    Year  Season            City       Sport                        Event  \
# 0  1992  Summer       Barcelona  Basketball  Basketball Men's Basketball
# 1  1920  Summer       Antwerpen    Football      Football Men's Football
# 2  1900  Summer           Paris  Tug-Of-War  Tug-Of-War Men's Tug-Of-War
# 3  2002  Winter  Salt Lake City  Ice Hockey  Ice Hockey Men's Ice Hockey
# 4  2014  Winter           Sochi  Ice Hockey  Ice Hockey Men's Ice Hockey
#
#       category
# 0  Team Sports
# 1  Team Sports
# 2  Team Sports
# ...

# %%
df.describe()
# Out:
#                 Age        Height        Weight          Year
# count  45983.000000  45983.000000  45983.000000  45983.000000
# mean      25.297393    184.362112     80.600831   1980.914860
# std        4.200791     11.117615     12.863592     28.483169
# min       11.000000    132.000000     28.000000   1900.000000
# 25%       22.000000    176.000000     71.000000   1964.000000
# 50%       25.000000    185.000000     83.000000   1988.000000
# 75%       28.000000    195.000000     90.000000   2004.000000
# max       60.000000    226.000000    156.000000   2016.000000

# %%
df.corr(numeric_only = True)
# Out:
#              Age    Height    Weight      Year
# Age     1.000000  0.059385  0.103910  0.093934
# Height  0.059385  1.000000  0.855649 -0.295706
# Weight  0.103910  0.855649  1.000000 -0.245651
# Year    0.093934 -0.295706 -0.245651  1.000000

# %%
sns.heatmap(df.corr(numeric_only = True),cmap= 'coolwarm',square = True,annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x= df['Height'])
# Out:
# <Axes: xlabel='Height'>

# %%
sns.boxplot(x= df['Weight'])
# Out:
# <Axes: xlabel='Weight'>

# %%
df['Height'].skew()
# Out:
# -0.33017851533995446

# %%
sns.distplot(df['Height'],hist = False)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\3128262408.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'],hist = False)
# <Axes: xlabel='Height', ylabel='Density'>

# %%
df['Weight'].skew()
# Out:
# -0.2879658963855406

# %%
sns.distplot(df['Weight'],hist = False)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\394993695.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'],hist = False)
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.7157738652412531

# %%
sns.distplot(df['Age'],hist = False)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\3394592707.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist = False)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## So I Have Check The Data Distubution and variance and skewness

# %%
q1 = np.percentile(df['Age'], 25)
q3 = np.percentile(df['Age'],75)
iqr = q3 - q1
iqr
upper_limit_age = q3 + 1.5*iqr
lower_limit_age = q1 - 1.5*iqr
print('upper ',upper_limit_age)
print('lower',lower_limit_age)
# Out:
# upper  37.0
# lower 13.0

# %%
q1 = np.percentile(df['Height'], 25)
q3 = np.percentile(df['Height'],75)
iqr = q3 - q1
iqr
upper_limit_height = q3 + 1.5*iqr
lower_limit_height = q1 - 1.5*iqr
print('upper ',upper_limit_height)
print('lower',lower_limit_height)
# Out:
# upper  223.5
# lower 147.5

# %%
q1 = np.percentile(df['Weight'], 25)
q3 = np.percentile(df['Weight'],75)
iqr = q3 - q1
iqr
upper_limit_weight = q3 + 1.5*iqr
lower_limit_weight = q1 - 1.5*iqr
print('upper ',upper_limit_weight)
print('lower',lower_limit_weight)
# Out:
# upper  118.5
# lower 42.5

# %%
q1 = np.percentile(df['Year'], 25)
q3 = np.percentile(df['Year'],75)
iqr = q3 - q1
iqr
upper_limit_year = q3 + 1.5*iqr
lower_limit_year = q1 - 1.5*iqr
print('upper ',upper_limit_year)
print('lower',lower_limit_year)
# Out:
# upper  2064.0
# lower 1904.0

# %%
# this new data base create.i have remove all outlier in this dataset
df1 = df[(df['Age'] > lower_limit_age) & (df['Age'] < upper_limit_age) & (df['Height'] > lower_limit_height) & (df['Height'] < upper_limit_height) & (df['Year'] > lower_limit_year) & (df['Weight'] > lower_limit_weight) & (df['Weight'] < upper_limit_weight)]

# %%
plt.figure(figsize = (8,20))
plt.subplot(3,1,1)
sns.boxplot(x = df1['Age'])
plt.subplot(3,1,2)
sns.boxplot(x = df1['Height'])
plt.subplot(3,1,3)
sns.boxplot(x = df1['Weight'])
# Out:
# <Axes: xlabel='Weight'>

# %%
# i have remove all the outlier in the data

# %%
y1 = df1['Year'].skew()
h1 = df1['Height'].skew()
w1 = df1['Weight'].skew()
a1 = df1['Age'].skew()
y = df['Year'].skew()
h = df['Height'].skew()
w = df['Weight'].skew()
a = df['Age'].skew()
print(f'After remove outlier Year skewness:{y1} and Before remove outlier skewness:{y}')
print(f'After remove outlier Height skewness:{h1} and Before remove outlier skewness:{h}')
print(f'After remove outlier Weight skewness:{w1} and Before remove outlier skewness:{w}')
print(f'After remove outlier Age skewness:{a1} and Before remove outlier skewness:{a}')
# Out:
# After remove outlier Year skewness:-0.8348466580554796 and Before remove outlier skewness:-0.881570875974247
# After remove outlier Height skewness:-0.3112969750253073 and Before remove outlier skewness:-0.33017851533995446
# After remove outlier Weight skewness:-0.3346015415682667 and Before remove outlier skewness:-0.2879658963855406
# After remove outlier Age skewness:0.39423150387010536 and Before remove outlier skewness:0.7157738652412531

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 25))
#age plot
sns.distplot(df1['Age'], hist=False, label='Age', ax=axes[0, 0],color = 'red')
axes[0, 0].set_title('Age Column After Remove Outlier')

sns.distplot(df['Age'], hist=False, label='Age', ax=axes[0, 1])
axes[0, 1].set_title('Age Column Before Remove Outlier')



# Plot Height
sns.distplot(df1['Height'], hist=False, label='Height', ax=axes[1, 0],color = 'red')
axes[1, 0].set_title('Height Column After Remove Outlier')

sns.distplot(df['Height'], hist=False, label='Height', ax=axes[1, 1])
axes[1, 1].set_title('Height Column Before Remove Outlier')


#plot Year
sns.distplot(df1['Year'], hist=False, label='Year', ax=axes[2, 0],color = 'red')
axes[2, 0].set_title('Year Column After Remove Outlier')

sns.distplot(df['Year'], hist=False, label='year', ax=axes[2, 1])
axes[2, 1].set_title('Year Column Before Remove Outlier')



# Plot Weight
sns.distplot(df1['Weight'], hist=False, label='weight',color = 'red', ax=axes[3, 0])
axes[3, 0].set_title('Weight Column After Remove Outlier')

sns.distplot(df['Weight'], hist=False, label='Weight', ax=axes[3, 1])
axes[3, 1].set_title('Weight Column Before Remove Outlier')


# Adjust layout
plt.tight_layout()
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\1784618655.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Age'], hist=False, label='Age', ax=axes[0, 0],color = 'red')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\1784618655.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df1.describe()
# Out:
#                 Age        Height        Weight          Year
# count  44859.000000  44859.000000  44859.000000  44859.000000
# mean      25.144765    184.226131     80.437627   1981.754475
# std        3.917787     11.024644     12.676356     27.361596
# min       14.000000    149.000000     43.000000   1906.000000
# 25%       22.000000    176.000000     71.000000   1964.000000
# 50%       25.000000    185.000000     82.000000   1988.000000
# 75%       28.000000    195.000000     90.000000   2004.000000
# max       36.000000    223.000000    118.000000   2016.000000

# %%
df1.head()
# Out:
#                         Name Sex   Age  Height  Weight     Team  NOC  Year  \
# 0                  A Dijiang   M  24.0   180.0    80.0    China  CHN  1992
# 1        Gunnar Nielsen Aaby   M  24.0   195.0    90.0  Denmark  DEN  1920
# 3           Antti Sami Aalto   M  26.0   186.0    96.0  Finland  FIN  2002
# 4   Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN  2014
# 5  Ragnhild Margrethe Aamodt   F  27.0   163.0    90.0   Norway  NOR  2008
#
#    Season            City       Sport                        Event  \
# 0  Summer       Barcelona  Basketball  Basketball Men's Basketball
# 1  Summer       Antwerpen    Football      Football Men's Football
# 3  Winter  Salt Lake City  Ice Hockey  Ice Hockey Men's Ice Hockey
# 4  Winter           Sochi  Ice Hockey  Ice Hockey Men's Ice Hockey
# 5  Summer         Beijing    Handball    Handball Women's Handball
#
#       category
# 0  Team Sports
# 1  Team Sports
# 3  Team Sports
# 4  Team Sports
# 5  Team Sports

# %%
ax = sns.countplot(x = df1['Sex'],palette = list('rgb'))
for i in range(df1.Sex.nunique()):
    ax.bar_label(ax.containers[i])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\911433692.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = df1['Sex'],palette = list('rgb'))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\911433692.py:1: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   ax = sns.countplot(x = df1['Sex'],palette = list('rgb'))

# %%
d_age = df1.groupby('Sport')['Sex'].count()

plt.figure(figsize = (15,6))
ax = sns.countplot(x = df1['Sport'],hue = df1['Sex'])
for i in range(df1.Sex.nunique()):
    ax.bar_label(ax.containers[i]) 
ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\2935682007.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)

# %%
def age_c(data):
    if 10<= data <=20:
        return '10-20'
    elif 21<= data <=30:
        return '21-30'
    elif 31<= data <=40:
        return '31 - 40'
df1['Age_Group'] = df1['Age'].apply(age_c)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\1072532287.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Age_Group'] = df1['Age'].apply(age_c)

# %%
df1
# Out:
#                                Name Sex   Age  Height  Weight           Team  \
# 0                         A Dijiang   M  24.0   180.0    80.0          China
# 1               Gunnar Nielsen Aaby   M  24.0   195.0    90.0        Denmark
# 3                  Antti Sami Aalto   M  26.0   186.0    96.0        Finland
# 4          Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0        Finland
# 5         Ragnhild Margrethe Aamodt   F  27.0   163.0    90.0         Norway
# ...                             ...  ..   ...     ...     ...            ...
# 45978      Fernando scar Zylberberg   M  27.0   168.0    76.0      Argentina
# 45979    James Francis "Jim" Zylker   M  21.0   175.0    75.0  United States
# 45980  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0         Russia
# 45981  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0         Russia
# 45982        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0        Belarus
#
# ...

# %%
plt.figure(figsize = (15,6))
ax = sns.countplot(x = df1['Age_Group'],hue = df1['Sex'])
for i in range(df1.Sex.nunique()):
    ax.bar_label(ax.containers[i]) 
ax.set_xticklabels(labels = ['10-20','21-30','31-40'])
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\2013322151.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels = ['10-20','21-30','31-40'])

# %%
age_mean = round(df1.groupby(['Sport','Sex'])['Age'].mean()).reset_index()
# age_mean

# %%
plt.figure(figsize = (15,6))
ax = sns.barplot(x=age_mean['Sport'],y = age_mean['Age'],hue = df1['Sex'])
for i in range(df1.Sex.nunique()):
    ax.bar_label(ax.containers[i]) 
ax.set_title('Average Age Ratio by Gender And Sport')
ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\2230556063.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)

# %%
wg_mean = round(df1.groupby(['Sport','Sex'])['Weight'].mean()).reset_index()
wg_mean
hg_mean = round(df1.groupby(['Sport','Sex'])['Height'].mean()).reset_index()
hg_mean
# Out:
#                     Sport Sex  Height
# 0              Basketball   F   182.0
# 1              Basketball   M   195.0
# 2        Beach Volleyball   F   179.0
# 3        Beach Volleyball   M   193.0
# 4                Football   F   168.0
# 5                Football   M   184.0
# 6                Handball   F   176.0
# 7                Handball   M   189.0
# 8                  Hockey   F   167.0
# 9                  Hockey   M   182.0
# 10             Ice Hockey   F   168.0
# 11             Ice Hockey   M   184.0
# 12               Lacrosse   M   195.0
# 13                   Polo   M   194.0
# 14                 Rowing   F   178.0
# 15                 Rowing   M   189.0
# 16                  Rugby   M   185.0
# 17           Rugby Sevens   F   168.0
# 18           Rugby Sevens   M   183.0
# 19  Synchronized Swimming   F   170.0
# 20             Tug-Of-War   M   193.0
# 21             Volleyball   F   180.0
# 22             Volleyball   M   193.0
# 23             Water Polo   F   176.0
# ...

# %%
plt.figure(figsize = (15,6))

ax = sns.barplot(x=wg_mean['Sport'],y = wg_mean['Weight'],hue = df1['Sex'])
for i in range(df1.Sex.nunique()):
    ax.bar_label(ax.containers[i]) 
ax.set_title('Average Weight Ratio by Gender And Sport')
ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\1995119555.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)

# %%
plt.figure(figsize = (15,6))

ax = sns.barplot(x=hg_mean['Sport'],y = hg_mean['Height'],hue = df1['Sex'])
for i in range(df1.Sex.nunique()):
    ax.bar_label(ax.containers[i]) 
ax.set_title('Average Height Ratio by Gender And Sport')
ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\2987204389.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels = ['Basketball','Football','Ice Hockey','Handball','Water Polo','Hockey','Rowing','Volleyball','Synchronized Swimming','Rugby Sevens','Beach Volleyball''Lacrosse','Polo','Tug-Of-War','Rugby'],rotation = 90)

# %%
plt.figure(figsize = (8,15))
plt.subplot(3,1,1)
ax = sns.lineplot(x = df1['Year'],y = df1['Age'],hue = df1['Sex'])
ax.set_title('Age')
plt.subplot(3,1,2)
ax = sns.lineplot(y = df1['Weight'],x = df1['Age'],hue = df1['Sex'])
ax.set_title('Weight')
plt.subplot(3,1,3)
ax = sns.lineplot(y = df1['Height'],x = df1['Age'],hue = df1['Sex'])
ax.set_title('Height')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20,6))
team_p =   df1.groupby(['Team'])['Name'].count().reset_index().sort_values(by = 'Name',ascending = False).head(15)
ax = sns.barplot(x  = 'Team',y = team_p['Name'], data = team_p,palette = list('rgb'))
for i in range(team_p.Name.nunique()):
    ax.bar_label(ax.containers[i])
plt.title('Top 15 Team most highest player player games')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\4087681128.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x  = 'Team',y = team_p['Name'], data = team_p,palette = list('rgb'))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9756\4087681128.py:3: UserWarning:
# The palette list has fewer values (3) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x  = 'Team',y = team_p['Name'], data = team_p,palette = list('rgb'))
# Text(0.5, 1.0, 'Top 15 Team most highest player player games')

# %%
d = df1.groupby(['Year','Season'])['Name'].count().reset_index()
sns.scatterplot(x =d['Year'],y = d['Name'],hue = d['Season'])
# Out:
# <Axes: xlabel='Year', ylabel='Name'>
